# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets
iris = datasets.load_iris()

# %%
X = iris.data
y = iris.target

# %%
X[:10,:]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=666)

# %% [markdown]
# ### Sklearn中的StandardScaler

# %%
### preprocessing数据预处理
from sklearn.preprocessing import StandardScaler

# %%
standardScaler = StandardScaler()

# %%
standardScaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
standardScaler.mean_
# Out:
# array([5.83416667, 3.0825    , 3.70916667, 1.16916667])

# %%
standardScaler.scale_
# Out:
# array([0.81019502, 0.44076874, 1.76295187, 0.75429833])

# %%
X_train = standardScaler.transform(X_train)

# %%
X_train
# Out:
# array([[ -8.31938844,  -4.84447074,  -2.84692759,  -3.25338812],
#        [ -8.62407329,  -7.41811448,  -2.84692759,  -3.25338812],
#        [ -7.4053339 ,  -8.44757198,  -1.97820153,  -1.32005633],
#        [ -6.64362178,  -5.35919949,  -1.55992602,   0.43751802],
#        [ -8.31938844,  -9.99175822,  -2.33212697,  -1.6715712 ],
#        [ -5.4248824 ,  -6.38865698,  -1.7851513 ,  -1.14429889],
#        [ -6.79596421,  -9.47702948,  -1.49557594,  -1.14429889],
#        [ -4.51082786,  -7.41811448,  -1.17382555,   0.08600315],
#        [ -8.16704602,  -1.75609825,  -2.81475256,  -3.42914555],
#        [ -6.64362178, -11.53594447,  -1.84950137,  -0.96854146],
#        [ -4.96785513,  -7.93284323,  -1.27035067,  -0.44126915],
#        [ -6.33893694,  -6.38865698,  -1.59210106,   0.43751802],
#        [ -6.94830663,  -5.35919949,  -1.84950137,  -0.79278402],
#        [ -8.16704602,  -8.96230073,  -2.04255161,  -1.14429889],
#        [ -7.86236117,  -3.81501324,  -2.81475256,  -3.25338812],
#        [ -8.01470359,  -3.81501324,  -2.81475256,  -3.25338812],
#        [ -8.47173087,  -4.84447074,  -2.78257752,  -2.55035837],
#        [ -9.38578541,  -7.93284323,  -2.84692759,  -3.25338812],
#        [ -7.25299148,  -8.96230073,  -2.04255161,  -1.49581376],
#        [ -8.16704602,  -5.35919949,  -2.84692759,  -3.25338812],
#        [ -9.08110056,  -5.35919949,  -2.84692759,  -3.07763068],
#        [ -6.18659451,  -6.38865698,  -1.65645114,  -0.08975428],
#        [ -7.4053339 ,  -7.93284323,  -1.94602649,  -1.32005633],
#        [ -6.03425209,  -7.41811448,  -1.88167641,  -1.14429889],
#        [ -6.94830663,  -7.93284323,  -1.84950137,  -0.96854146],
#        [ -8.92875814,  -6.38865698,  -2.78257752,  -3.25338812],
#        [ -8.62407329,  -6.90338573,  -2.81475256,  -3.42914555],
#        [ -5.88190967,  -6.90338573,  -1.49557594,   0.61327546],
#        [ -6.49127936,  -8.96230073,  -1.72080122,  -0.44126915],
#        [ -6.79596421,  -8.44757198,  -1.7851513 ,  -1.49581376],
#        [ -6.64362178,  -8.44757198,  -1.75297626,  -0.44126915],
#        [ -7.4053339 ,  -0.211912  ,  -2.81475256,  -2.90187324],
#        [ -6.49127936,  -9.99175822,  -1.72080122,  -0.96854146],
#        [ -6.33893694,  -7.93284323,  -1.91385145,  -1.32005633],
#        [ -8.31938844,  -3.30028449,  -2.6860524 ,  -2.90187324],
#        [ -5.72956724,  -8.44757198,  -1.75297626,  -1.14429889],
#        [ -8.31938844,  -4.84447074,  -2.84692759,  -3.07763068],
#        [ -9.53812783,  -7.41811448,  -2.94345271,  -3.42914555],
#        [ -7.10064905,  -7.41811448,  -1.65645114,  -0.44126915],
#        [ -6.33893694,  -8.44757198,  -1.49557594,   0.08600315],
#        [ -7.55767632,  -8.44757198,  -1.72080122,  -0.08975428],
#        [ -7.71001875, -10.50648697,  -2.10690169,  -1.84732863],
#        [ -5.57722482,  -6.90338573,  -1.72080122,  -0.96854146],
#        [ -6.49127936,  -5.35919949,  -1.49557594,   0.61327546],
#        [ -6.18659451,  -7.41811448,  -1.43122586,   0.26176059],
#        [ -7.4053339 ,  -3.30028449,  -2.75040248,  -3.07763068],
#        [ -6.03425209,  -7.93284323,  -1.81732634,  -1.32005633],
#        [ -5.88190967,  -5.87392823,  -1.4634009 ,   0.78903289],
#        [ -8.77641571,  -7.41811448,  -2.84692759,  -3.42914555],
#        [ -8.47173087,  -4.32974199,  -2.84692759,  -3.25338812],
#        [ -6.94830663,  -7.41811448,  -1.75297626,  -0.44126915],
#        [ -8.47173087,  -7.41811448,  -2.78257752,  -3.25338812],
#        [ -6.79596421,  -7.41811448,  -1.72080122,  -0.44126915],
#        [ -6.33893694,  -6.90338573,  -1.52775098,  -0.44126915],
#        [ -8.31938844,  -3.81501324,  -2.81475256,  -2.90187324],
#        [ -7.4053339 ,  -7.41811448,  -1.94602649,  -1.49581376],
#        [ -8.47173087,  -4.84447074,  -2.87910263,  -3.07763068],
#        [ -8.31938844,  -3.30028449,  -2.81475256,  -3.07763068],
#        [ -9.08110056,  -6.38865698,  -2.84692759,  -3.25338812],
#        [ -7.86236117,  -7.41811448,  -1.84950137,  -0.96854146],
#        [ -6.18659451,  -8.44757198,  -1.81732634,  -0.96854146],
#        [ -6.79596421,  -8.44757198,  -2.01037657,  -1.32005633],
#        [ -8.77641571,  -5.35919949,  -2.78257752,  -3.25338812],
#        [ -8.31938844,  -5.87392823,  -2.75040248,  -2.72611581],
#        [ -7.25299148,  -8.96230073,  -1.65645114,  -0.26551172],
#        [ -7.55767632,  -7.41811448,  -1.97820153,  -1.32005633],
#        [ -6.49127936,  -8.44757198,  -1.65645114,  -0.96854146],
#        [ -5.88190967,  -5.87392823,  -1.4634009 ,   0.08600315],
#        [ -5.12019755,  -7.41811448,  -1.43122586,  -0.79278402],
#        [ -5.88190967,  -7.41811448,  -1.6242761 ,   0.43751802],
#        [ -8.62407329,  -6.90338573,  -2.81475256,  -3.42914555],
#        [ -8.62407329,  -9.99175822,  -1.84950137,  -0.61702659],
#        [ -7.4053339 ,  -9.99175822,  -1.68862618,  -0.08975428],
#        [ -8.62407329, -10.50648697,  -2.23560185,  -1.84732863],
#        [ -7.71001875, -10.50648697,  -2.07472665,  -1.6715712 ],
#        [ -5.88190967,  -9.99175822,  -1.43122586,  -0.44126915],
#        [ -6.18659451,  -7.41811448,  -1.52775098,  -0.44126915],
#        [ -7.4053339 ,  -9.47702948,  -2.17125177,  -1.84732863],
#        [ -6.94830663, -11.53594447,  -1.68862618,  -0.96854146],
#        [ -5.88190967,  -6.90338573,  -1.7851513 ,  -0.96854146],
#        [ -8.62407329,  -6.90338573,  -2.81475256,  -3.42914555],
#        [ -6.49127936,  -9.99175822,  -1.68862618,  -0.26551172],
#        [ -8.92875814,  -6.38865698,  -2.87910263,  -3.25338812],
#        [ -6.94830663,  -8.96230073,  -1.65645114,  -0.79278402],
#        [ -7.25299148,  -9.47702948,  -2.01037657,  -1.49581376],
#        [ -5.57722482,  -6.38865698,  -1.4634009 ,   0.43751802],
#        [ -9.38578541,  -7.41811448,  -2.87910263,  -3.25338812],
#        [ -5.27253997,  -7.41811448,  -1.39905082,   0.08600315],
#        [ -5.72956724,  -6.38865698,  -1.39905082,   0.43751802],
#        [ -8.16704602,  -4.84447074,  -2.81475256,  -3.25338812],
#        [ -4.05380059,  -3.30028449,  -1.23817563,  -0.08975428],
#        [ -6.33893694,  -8.44757198,  -1.49557594,   0.26176059],
#        [ -7.55767632,  -7.93284323,  -2.13907673,  -1.32005633],
#        [ -7.71001875,  -1.2413695 ,  -2.84692759,  -3.25338812],
#        [ -8.77641571,  -7.41811448,  -2.84692759,  -3.07763068],
#        [ -6.49127936,  -7.93284323,  -1.49557594,  -0.44126915],
#        [ -9.38578541,  -6.38865698,  -2.87910263,  -3.25338812],
#        [ -7.86236117,  -2.78555574,  -2.75040248,  -2.90187324],
#        [ -8.47173087,  -5.35919949,  -2.78257752,  -2.90187324],
#        [ -5.88190967,  -7.41811448,  -1.68862618,  -0.61702659],
#        [ -7.86236117,  -2.78555574,  -2.87910263,  -2.90187324],
#        [ -4.35848543,  -8.44757198,  -1.14165051,  -0.08975428],
#        [ -7.55767632,  -8.96230073,  -1.94602649,  -1.32005633],
#        [ -5.72956724,  -7.41811448,  -1.52775098,   0.08600315],
#        [ -7.71001875,  -4.84447074,  -2.87910263,  -3.25338812],
#        [ -8.77641571,  -5.35919949,  -2.6860524 ,  -3.25338812],
#        [ -7.86236117,  -5.35919949,  -2.75040248,  -3.25338812],
#        [ -4.35848543,  -3.30028449,  -1.14165051,   0.26176059],
#        [ -5.57722482,  -6.90338573,  -1.55992602,   0.08600315],
#        [ -7.55767632,  -9.99175822,  -2.04255161,  -1.6715712 ],
#        [ -8.31938844,  -5.35919949,  -2.81475256,  -3.25338812],
#        [ -8.31938844,  -3.30028449,  -2.78257752,  -3.25338812],
#        [ -6.79596421,  -7.93284323,  -1.7851513 ,  -1.14429889],
#        [ -7.25299148,  -2.27082699,  -2.91127767,  -3.25338812],
#        [ -8.47173087, -12.56540197,  -2.17125177,  -1.84732863],
#        [ -6.33893694,  -6.38865698,  -1.84950137,  -0.96854146],
#        [ -6.79596421,  -7.41811448,  -1.81732634,  -1.14429889],
#        [ -7.10064905,  -6.38865698,  -1.75297626,  -0.44126915],
#        [ -6.94830663, -11.53594447,  -2.01037657,  -1.84732863],
#        [ -4.8155127 ,  -8.44757198,  -1.33470074,  -0.26551172]])

# %%
X_test_standard = standardScaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_clf = KNeighborsClassifier(n_neighbors=3)

# %%
knn_clf.fit(X_test, y_test)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=3, p=2,
#            weights='uniform')

# %%
knn_clf.score(X_test, y_test)
# Out:
# 1.0
