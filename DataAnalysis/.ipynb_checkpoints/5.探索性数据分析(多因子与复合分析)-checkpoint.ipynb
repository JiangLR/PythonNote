# %% [markdown]
# ### 理论铺垫
# 1. 假设检验与方差检验
# 2. 相关系数：皮尔逊，斯皮尔曼
# 3. 回归：线性回归
# 4. PCA与奇异值分析

# %% [markdown]
# #### 假设检验
#     * 根据假设条件，从样本推测总体，推测假设成立的概率有多大
# 1. 建立原假设H0(包含等号)，H0的反命题为H1，也叫备择假设
# 2. 选择检验统计量
# 3. 根据显著水平(一般为0.05)，确定拒绝域
# 4. 计算p值或样本统计量，做出判断
# ![image.png](attachment:image.png)
